# %%
import pandas as pd
df = pd.read_csv("data/arschools.csv")
daspp = df['DistrictAverageSpendingPerPupil'].dropna()
daspp.describe()
# Out:
# count     1123.000000
# mean      9707.036750
# std       1952.655378
# min          0.000000
# 25%       8708.100000
# 50%       9404.590000
# 75%      10452.130000
# max      20312.300000
# Name: DistrictAverageSpendingPerPupil, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(daspp, bins=50, normed=1, facecolor='#a661e5')
plt.show()
